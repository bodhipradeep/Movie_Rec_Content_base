# %% [markdown]
# ## Colabrative Filter : Alternating Least Squares

# %% [markdown]
# [Dataset: https://grouplens.org/datasets/movielens/]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import re

# %%
movies = pd.read_csv("movies.csv")
tags = pd.read_csv("tags.csv")
links = pd.read_csv("links.csv")

# %%
print(movies.columns, "\n", tags.columns, "\n", links.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
#  Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')
#  Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')

# %%
movie_links = movies.merge(links, on='movieId')

movies['imdb_url'] = movie_links['imdbId'].apply(lambda x: f"https://www.imdb.com/title/tt{int(x):07d}/")
movies['tmdb_url'] = movie_links['tmdbId'].apply(lambda x: f"https://www.themoviedb.org/movie/{int(x)}" if not pd.isna(x) else None)

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 87580   292731           The Monroy Affaire (2022)
# 87581   292737          Shelter in Solitude (2023)
# 87582   292753                         Orca (2023)
# 87583   292755              The Angry Breed (1968)
# 87584   292757           Race to the Summit (2023)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 87580                                        Drama
# 87581                                 Comedy|Drama
# 87582                                        Drama
# 87583                                        Drama
# 87584                 Action|Adventure|Documentary
#
#                                      imdb_url  \
# 0       https://www.imdb.com/title/tt0114709/
# 1       https://www.imdb.com/title/tt0113497/
# 2       https://www.imdb.com/title/tt0113228/
# 3       https://www.imdb.com/title/tt0114885/
# 4       https://www.imdb.com/title/tt0113041/
# ...                                       ...
# 87580  https://www.imdb.com/title/tt26812510/
# 87581  https://www.imdb.com/title/tt14907358/
# 87582  https://www.imdb.com/title/tt12388280/
# 87583   https://www.imdb.com/title/tt0064027/
# 87584  https://www.imdb.com/title/tt28995566/
#
#                                        tmdb_url
# 0          https://www.themoviedb.org/movie/862
# 1         https://www.themoviedb.org/movie/8844
# 2        https://www.themoviedb.org/movie/15602
# 3        https://www.themoviedb.org/movie/31357
# 4        https://www.themoviedb.org/movie/11862
# ...                                         ...
# 87580  https://www.themoviedb.org/movie/1032473
# 87581   https://www.themoviedb.org/movie/986674
# 87582   https://www.themoviedb.org/movie/948139
# 87583   https://www.themoviedb.org/movie/182776
# 87584  https://www.themoviedb.org/movie/1174725
#
# [87585 rows x 5 columns]

# %%
movies.isnull().sum()
# Out:
# movieId       0
# title         0
# genres        0
# imdb_url      0
# tmdb_url    124
# dtype: int64

# %%
tags.isnull().sum()
# Out:
# userId        0
# movieId       0
# tag          17
# timestamp     0
# dtype: int64

# %%
tags.head()
# Out:
#    userId  movieId          tag   timestamp
# 0      22    26479  Kevin Kline  1583038886
# 1      22    79592     misogyny  1581476297
# 2      22   247150   acrophobia  1622483469
# 3      34     2174        music  1249808064
# 4      34     2174        weird  1249808102

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                                 imdb_url  \
# 0  https://www.imdb.com/title/tt0114709/
# 1  https://www.imdb.com/title/tt0113497/
# 2  https://www.imdb.com/title/tt0113228/
# 3  https://www.imdb.com/title/tt0114885/
# 4  https://www.imdb.com/title/tt0113041/
#
#                                  tmdb_url
# 0    https://www.themoviedb.org/movie/862
# 1   https://www.themoviedb.org/movie/8844
# 2  https://www.themoviedb.org/movie/15602
# 3  https://www.themoviedb.org/movie/31357
# 4  https://www.themoviedb.org/movie/11862

# %%
# tags_grouped = tags.groupby('movieId')['tag'].apply(lambda x: " ".join(x)).reset_index()
tags_grouped = tags.groupby('movieId')['tag'].apply(lambda x: " ".join(str(tag) for tag in x if pd.notnull(tag))).reset_index()

# %%
movies = movies.merge(tags_grouped, on='movieId', how='left')

# %%
movies['feature'] = (movies['genres'].fillna('') + ' ' +movies['tag'].fillna(''))

# %%
movies["feature"] = movies["feature"].str.replace("|", " ")

# %%
def clean_text(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Remove special chars
    return text.lower().strip()

# %%
movies['feature'] = movies['feature'].apply(clean_text)

# %%
movies['feature'].shape
# Out:
# (87585,)

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                                 imdb_url  \
# 0  https://www.imdb.com/title/tt0114709/
# 1  https://www.imdb.com/title/tt0113497/
# 2  https://www.imdb.com/title/tt0113228/
# 3  https://www.imdb.com/title/tt0114885/
# 4  https://www.imdb.com/title/tt0113041/
#
#                                  tmdb_url  \
# 0    https://www.themoviedb.org/movie/862
# 1   https://www.themoviedb.org/movie/8844
# 2  https://www.themoviedb.org/movie/15602
# 3  https://www.themoviedb.org/movie/31357
# 4  https://www.themoviedb.org/movie/11862
#
#                                                  tag  \
# 0  children Disney animation children Disney Disn...
# 1  Robin Williams fantasy Robin Williams time tra...
# 2  comedinha de velhinhos engraÃƒÂ§ada comedinha ...
# 3  characters slurs based on novel or book chick ...
# 4  Fantasy pregnancy remake family Steve Martin s...
#
#                                              feature
# 0  adventure animation children comedy fantasy ch...
# 1  adventure children fantasy robin williams fant...
# 2  comedy romance comedinha de velhinhos engraada...
# 3  comedy drama romance characters slurs based on...
# 4  comedy fantasy pregnancy remake family steve m...

# %%
vector = TfidfVectorizer(stop_words="english")
feature_vector = vector.fit_transform(movies["feature"])

# %%
print(feature_vector)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1492038 stored elements and shape (87585, 48958)>
#   Coords	Values
#   (0, 1345)	0.07942440479539474
#   (0, 2327)	0.31380816996360966
#   (0, 8445)	0.08180408016462808
#   (0, 9464)	0.04258731256471066
#   (0, 15502)	0.02644779528931117
#   (0, 12653)	0.22125929895685947
#   (0, 33225)	0.7015465878279963
#   (0, 17163)	0.1605788892893002
#   (0, 45230)	0.007781033095408701
#   (0, 46571)	0.004073570262882824
#   (0, 8898)	0.0827916133861187
#   (0, 16983)	0.1190244510307698
#   (0, 9656)	0.1504959751685042
#   (0, 44607)	0.18629497573174067
#   (0, 2326)	0.07939019071541825
#   (0, 8990)	0.12624328550668593
#   (0, 15445)	0.10015442115042575
#   (0, 44312)	0.20190104135840717
#   (0, 19352)	0.2623147867892257
#   (0, 665)	0.021664708431963397
#   (0, 20939)	0.09840395565772318
#   (0, 44117)	0.04061626009997883
#   (0, 44823)	0.036002687174594566
#   (0, 1058)	0.007024880868148313
#   (0, 35528)	0.004101300026856605
#   :	:
#   (87570, 12883)	1.0
#   (87571, 12883)	1.0
#   (87572, 9464)	0.5888642817941833
#   (87572, 1164)	0.8082319330656398
#   (87573, 13221)	1.0
#   (87574, 9464)	0.7654284431981262
#   (87574, 13221)	0.6435210162405678
#   (87575, 13221)	1.0
#   (87576, 17709)	0.7070499745190213
#   (87576, 25460)	0.7071635832907769
#   (87577, 20651)	0.7402761658102429
#   (87577, 43955)	0.6723029066821634
#   (87578, 15445)	0.37756038965249394
#   (87578, 35962)	0.4571663329611611
#   (87578, 12883)	0.5623651783484801
#   (87578, 16009)	0.5763614337838575
#   (87579, 13221)	1.0
#   (87580, 13221)	1.0
#   (87581, 9464)	0.7654284431981262
#   (87581, 13221)	0.6435210162405678
#   (87582, 13221)	1.0
#   (87583, 13221)	1.0
#   (87584, 1345)	0.639575739849981
#   (87584, 1164)	0.5379364689683783
#   (87584, 12883)	0.549151371071021

# %%
# similarity = cosine_similarity(feature_vector)

# %%
knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=50)
knn.fit(feature_vector)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=50)

# %%
distance, indices = knn.kneighbors(feature_vector)

# %%
def recommend_movies(movie_index, top=50):
    print("Movies suggested for you \n")
    similar_indices = indices[movie_index][1:]
    for i, idx in enumerate(similar_indices, start=1):
        title = movies.loc[idx, 'title']
        url = movies.loc[idx, 'tmdb_url']
        print(f"{i}. {title} {url}")

# %%
# movie_name = input('Enter your favourite movie name: ').strip().lower()
# all_titles = movies['title'].tolist()

# # Case-insensitive substring match
# matches = [title for title in all_titles if movie_name in title.lower()]

# print(matches)

# %%
movie_name = input('Enter movie name: ').strip().lower()

# Find matches and extract year
matches = movies[movies['title'].str.lower().str.contains(movie_name)][['title', 'genres']]
matches['year'] = matches['title'].str.extract(r'\((\d{4})\)').astype(float)
matches = matches.dropna(subset=['year'])

# Automatically select the newest (most recent) match
if not matches.empty:
    close_match = matches.sort_values('year', ascending=False).iloc[0]['title']
    movieid = movies[movies.title == close_match].index[0]
    match_url = movies.loc[movieid, 'tmdb_url']
    print(f"Selected: {close_match} {match_url}")
else:
    print("No matching movies found.")
    close_match = None
# Out:
# Selected: Avengers: Infinity War - Part II (2019) https://www.themoviedb.org/movie/299534

# %%
movie_index = movies[movies.title == close_match].index[0]
print(movie_index)
# Out:
# 25102

# %%
recommend_movies(movie_index)
# Out:
# Movies suggested for you
#
# 1. Avengers: Age of Ultron (2015) https://www.themoviedb.org/movie/99861
# 2. Avengers: Infinity War - Part I (2018) https://www.themoviedb.org/movie/299536
# 3. Avengers, The (2012) https://www.themoviedb.org/movie/24428
# 4. Captain America: Civil War (2016) https://www.themoviedb.org/movie/271110
# 5. Thor: The Dark World (2013) https://www.themoviedb.org/movie/76338
# 6. Iron Man 2 (2010) https://www.themoviedb.org/movie/10138
# 7. Captain America: The Winter Soldier (2014) https://www.themoviedb.org/movie/100402
# 8. Iron Man (2008) https://www.themoviedb.org/movie/1726
# 9. Captain America: The First Avenger (2011) https://www.themoviedb.org/movie/1771
# 10. Iron Man 3 (2013) https://www.themoviedb.org/movie/68721
# 11. Thor (2011) https://www.themoviedb.org/movie/10195
# 12. Ant-Man (2015) https://www.themoviedb.org/movie/102899
# 13. Marvel Studios: Assembling a Universe (2014) https://www.themoviedb.org/movie/259910
# 14. Thor: Ragnarok (2017) https://www.themoviedb.org/movie/284053
# 15. Untitled Spider-Man Reboot (2017) https://www.themoviedb.org/movie/202249
# 16. Marvel One-Shot: Item 47 (2012) https://www.themoviedb.org/movie/119569
# 17. Ant-Man and the Wasp (2018) https://www.themoviedb.org/movie/363088
# 18. X-Men (2000) https://www.themoviedb.org/movie/36657
# 19. Doctor Strange in the Multiverse of Madness (2022) https://www.themoviedb.org/movie/453395
# 20. Fantastic Four: Rise of the Silver Surfer (2007) https://www.themoviedb.org/movie/1979
# 21. X2: X-Men United (2003) https://www.themoviedb.org/movie/36658
# 22. Incredible Hulk, The (2008) https://www.themoviedb.org/movie/1724
# 23. Spider-Man: Far from Home (2019) https://www.themoviedb.org/movie/429617
# 24. Spider-Man 2 (2004) https://www.themoviedb.org/movie/558
# 25. Black Panther: Wakanda Forever (2022) https://www.themoviedb.org/movie/505642
# 26. Marvel One-Shot: The Consultant (2011) https://www.themoviedb.org/movie/76122
# 27. Captain Marvel (2018) https://www.themoviedb.org/movie/299537
# 28. Marvel One-Shot: All Hail the King (2014) https://www.themoviedb.org/movie/253980
# 29. LEGO Marvel Spider-Man: Vexed By Venom (2019) https://www.themoviedb.org/movie/622230
# 30. X-Men: Days of Future Past (2014) https://www.themoviedb.org/movie/127585
# 31. X-Men: Apocalypse (2016) https://www.themoviedb.org/movie/246655
# 32. Elektra (2005) https://www.themoviedb.org/movie/9947
# 33. Marvel One-Shot: A Funny Thing Happened on the Way to Thor's Hammer (2011) https://www.themoviedb.org/movie/76535
# 34. Spider-Man 3 (2007) https://www.themoviedb.org/movie/559
# 35. Spider-Man (2002) https://www.themoviedb.org/movie/557
# 36. Fantastic Four (2015) https://www.themoviedb.org/movie/166424
# 37. Fantastic Four (2005) https://www.themoviedb.org/movie/9738
# 38. Black Panther (2017) https://www.themoviedb.org/movie/284054
# 39. Inhumans (2018) https://www.themoviedb.org/movie/299538
# 40. Marvel One-Shot: Agent Carter (2013) https://www.themoviedb.org/movie/211387
# 41. Guardians of the Galaxy (2014) https://www.themoviedb.org/movie/118340
# 42. Guardians of the Galaxy 2 (2017) https://www.themoviedb.org/movie/283995
# 43. Hulk: Where Monsters Dwell (2016) https://www.themoviedb.org/movie/422153
# 44. Eternals (2021) https://www.themoviedb.org/movie/524434
# 45. Teen Titans: The Judas Contract (2017) https://www.themoviedb.org/movie/408647
# 46. East Meets West (Dung sing sai tsau 2011) (2011) https://www.themoviedb.org/movie/85502
# 47. Doctor Strange (2016) https://www.themoviedb.org/movie/284052
# 48. Phenomenal and the Treasure of Tutankamen (1968) https://www.themoviedb.org/movie/243691
# 49. Blankman (1994) https://www.themoviedb.org/movie/20678

# %%
import pickle

# Save model
with open('knn_model.pkl', 'wb') as f:
    pickle.dump(knn, f)

# %%
with open("tfidf_matrix.pkl", "wb") as f:
    pickle.dump(feature_vector, f)

# %%
movies.to_csv("movies_processed.csv", index=False)
